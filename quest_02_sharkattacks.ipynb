# %%
# !pip install xlrd

# %%
import re
import pandas as pd
import numpy as np

#define path to xls
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
shark_attack_series_df = pd.read_excel(url)

# %%
shark_attack_series_df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
shark_attack_series_df.isnull()
# Out:
#        Date   Year   Type  Country  State  Location  Activity   Name    Sex  \
# 0     False  False  False    False   True     False     False  False  False
# 1     False  False  False    False  False     False     False  False  False
# 2     False  False  False    False  False     False     False  False  False
# 3     False  False  False    False  False     False     False  False  False
# 4     False  False  False    False  False     False     False  False  False
# ...     ...    ...    ...      ...    ...       ...       ...    ...    ...
# 6989  False  False  False    False  False     False     False  False  False
# 6990  False  False  False    False  False      True     False  False  False
# 6991  False  False  False    False  False     False     False  False  False
# 6992  False  False  False    False   True     False      True  False  False
# 6993  False  False  False    False  False     False     False  False  False
#
# ...

# %%
shark_attack_series_df.isna().any()
# Out:
# Date              False
# Year               True
# Type               True
# Country            True
# State              True
# Location           True
# Activity           True
# Name               True
# Sex                True
# Age                True
# Injury             True
# Fatal Y/N          True
# Time               True
# Species            True
# Source             True
# pdf                True
# href formula       True
# href               True
# Case Number        True
# Case Number.1      True
# original order     True
# Unnamed: 21        True
# Unnamed: 22        True
# dtype: bool

# %%
shark_attack_series_df.isna().sum()
# Out:
# Date                 0
# Year                 2
# Type                18
# Country             50
# State              483
# Location           565
# Activity           585
# Name               219
# Sex                579
# Age               2994
# Injury              35
# Fatal Y/N          561
# Time              3526
# Species           3132
# Source              19
# pdf                195
# href formula       200
# href               198
# Case Number        196
# Case Number.1      197
# original order     195
# Unnamed: 21       6993
# Unnamed: 22       6992
# dtype: int64

# %%
shark_attack_series_df.isna().sum(axis=1)
# Out:
# 0       9
# 1       8
# 2       8
# 3       8
# 4       8
#        ..
# 6989    5
# 6990    6
# 6991    5
# 6992    7
# 6993    4
# Length: 6994, dtype: int64

# %%
shark_attack_series_df.tail()
# Out:
#              Date  Year        Type             Country              State  \
# 6989  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6990  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6991    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 6992    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 6993    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 6989                          Roebuck Bay        Diving
# 6990                                  NaN  Pearl diving
# 6991                       Ocracoke Inlet      Swimming
# 6992                 Panama Bay 8ºN, 79ºW           NaN
# 6993  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  ... Species   \
# 6989                   male   M  NaN  ...      NaN
# 6990                  Ahmun   M  NaN  ...      NaN
# ...

# %%
shark_attack_series_df.drop(columns= ['pdf', 'href formula', 'href', 'Case Number', 'Case Number.1', 'original order', 'Unnamed: 21', 'Unnamed: 22'], inplace=True)

# %%
shark_attack_series_df
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-02-07 00:00:00  2025.0  Unprovoked    Turks and Caicos
# 1     2025-02-03 00:00:00  2025.0  Unprovoked           Australia
# 2     2025-01-23 00:00:00  2025.0  Unprovoked           Australia
# 3     2025-01-22 00:00:00  2025.0  Unprovoked           Australia
# 4     2025-01-11 00:00:00  2025.0    Provoked                 USA
# ...                   ...     ...         ...                 ...
# 6989          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6990          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6991            1900-1905     0.0  Unprovoked                 USA
# 6992            1883-1889     0.0  Unprovoked              PANAMA
# 6993            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   State                             Location      Activity  \
# 0                   NaN                  Thompson Cove Beach      Swimming
# ...

# %%
shark_attack_series_df.duplicated().sum()
# Out:
# 1

# %%
shark_attack_series_df.duplicated().any()
# Out:
# True

# %%
shark_attack_series_df.drop_duplicates(inplace=True)
shark_attack_series_df.reset_index(drop=True, inplace=True)
shark_attack_series_df
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-02-07 00:00:00  2025.0  Unprovoked    Turks and Caicos
# 1     2025-02-03 00:00:00  2025.0  Unprovoked           Australia
# 2     2025-01-23 00:00:00  2025.0  Unprovoked           Australia
# 3     2025-01-22 00:00:00  2025.0  Unprovoked           Australia
# 4     2025-01-11 00:00:00  2025.0    Provoked                 USA
# ...                   ...     ...         ...                 ...
# 6988          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6989          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6990            1900-1905     0.0  Unprovoked                 USA
# 6991            1883-1889     0.0  Unprovoked              PANAMA
# 6992            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   State                             Location      Activity  \
# 0                   NaN                  Thompson Cove Beach      Swimming
# ...
